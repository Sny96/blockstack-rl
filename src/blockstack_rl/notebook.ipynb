# %%
# %load_ext autoreload
# %autoreload 2
import importlib
import envs.env
import numpy as np
importlib.reload(envs.env)
from random import random
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
stack = envs.env.BlockstackEnv(10)
la = -1
for i in range(20):
    la = la+1/(20-i+1)
    action = np.array([la], dtype=np.float32)
    stack.step(action)
stack.render()
